# %% [raw]
# --->Program to return head of a reverse linked list through recursion.
# ##In that program we have a time complexity of O(n^2)

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
   
def reverse1(head):
    if head is None or head.next is None: #Base case
        return head

    small_head = reverse1(head.next) #Induction hypothesis
    curr = small_head
    while curr.next is not None:  #Through that loop we have to traverse for (n-1) elements which increase our time complexity
        curr = curr.next
    
    curr.next = head
    head.next = None
    return small_head

def TakeNodeInput():
    NodeArray=[int(x) for x in input().split()]
    head=None
    tail =None
    for ele in NodeArray:
        if ele == -1:
            break
        NewNode=Node(ele) 
        if head==None:
            head=NewNode
            tail=head
        else:
            tail.next = NewNode
            tail=tail.next
    return head

def PrintLL(head):
    while head!=None:
        print(str(head.data) + '->',end='')
        head=head.next
    print("None")   
    return

head=TakeNodeInput()
PrintLL(head)
head=reverse1(head)
PrintLL(head)
# Out:
# -1
# None
# None

# %% [raw]
# --->Program to return head of a reverse linked list through recursion.
# Here we follow an optimized way to do that and time complexity is O(n)

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
   
def reverse2(head):     #Here we return head and tail as both. 
    if head is None or head.next is None: #Base case
        return head,head
    small_head,tail = reverse2(head.next)
    tail.next  = head
    head.next = None
    return small_head,head

def reverse3(head):       #Here the code and time complexity is same and we only return head here and tail 
    if head is None or head.next is None: #is already present in it so we can can use that return only head.
        return head 
    small_head = reverse3(head.next)
    tail = head.next 
    tail.next = head 
    head.next = None
    return small_head

def TakeNodeInput():
    NodeArray=[int(x) for x in input().split()]
    head=None
    tail =None
    for ele in NodeArray:
        if ele == -1:
            break
        NewNode=Node(ele) 
        if head==None:
            head=NewNode
            tail=head
        else:
            tail.next = NewNode
            tail=tail.next
    return head

def PrintLL(head):
    while head!=None:
        print(str(head.data) + '->',end='')
        head=head.next
    print("None")   
    return

head1=TakeNodeInput()
PrintLL(head1)
head,tail=reverse2(head1)
PrintLL(head)
PrintLL(tail)
#head = reverse3(head1)
#PrintLL(head)
# Out:
# 1 2 3
# 1->2->3->None
# 3->2->1->None
# 1->None

# %% [markdown]
# Program to find mid-point of linked list in one iteration

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
   
def midpoint(head):
    if head is None:
        return head
    fast=head
    slow = head 
    while fast.next!=None and fast.next.next!=None:
        slow=slow.next
        fast=fast.next.next
    return slow
   

def TakeNodeInput():
    NodeArray=[int(x) for x in input().split()]
    head=None
    tail =None
    for ele in NodeArray:
        if ele == -1:
            break
        NewNode=Node(ele) 
        if head==None:
            head=NewNode
            tail=head
        else:
            tail.next = NewNode
            tail=tail.next
    return head

def PrintLL(head):
    while head!=None:
        print(str(head.data) + '->',end='')
        head=head.next
    print("None")   
    return

head=TakeNodeInput()
PrintLL(head)
head=midpoint(head)
if head is None:
    pass
else:
    print(head.data)
# Out:
# -1
# None

# %% [markdown]
# Program to merge two sorted Linked list

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
   
def mergell(h1,h2):
    if h1 is None and h2 is None:
         return 
    elif h1 is None:
         return h2
    elif  h2 is None:
         return h1
    elif h1.data <h2.data:
        fh=h1
        ft=h1
        h1=h1.next
    else:
        fh=h2
        ft=h2
        h2=h2.next
    while h1 is not None and h2 is not None:
        if h1.data < h2.data:
            ft.next= h1
            ft=ft.next
            h1=h1.next
        else:
            ft.next=h2
            ft=ft.next
            h2=h2.next
    if h1 is not None:
            ft.next= h1
            ft=ft.next
            h1=h1.next
    if h2 is not None:
            ft.next=h2
            ft=ft.next
            h2=h2.next        
    return fh

def TakeNodeInput():
    NodeArray=[int(x) for x in input().split()]
    head=None
    tail =None
    for ele in NodeArray:
        if ele == -1:
            break
        NewNode=Node(ele) 
        if head==None:
            head=NewNode
            tail=head
        else:
            tail.next = NewNode
            tail=tail.next
    return head

def PrintLL(head):
    while head!=None:
        print(str(head.data) + '->',end='')
        head=head.next
    print("None")   
    return

h1=TakeNodeInput()
h2=TakeNodeInput()
PrintLL(h1)
PrintLL(h2)
h=mergell(h1,h2)
PrintLL(h)

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
   
def midpoint(head):
    if head is None:
        return head
    fast=head
    slow = head 
    while fast.next!=None and fast.next.next!=None:
        slow=slow.next
        fast=fast.next.next
    return slow
   
def mergell(h1,h2):
    if h1 is None and h2 is None:
         return 
    elif h1 is None:
         return h2
    elif  h2 is None:
         return h1
    elif h1.data <h2.data:
        fh=h1
        ft=h1
        h1=h1.next
    else:
        fh=h2
        ft=h2
        h2=h2.next
    while h1 is not None and h2 is not None:
        if h1.data < h2.data:
            ft.next= h1
            ft=ft.next
            h1=h1.next
        else:
            ft.next=h2
            ft=ft.next
            h2=h2.next
    if h1 is not None:
            ft.next= h1
            ft=ft.next
            h1=h1.next
    if h2 is not None:
            ft.next=h2
            ft=ft.next
            h2=h2.next        
    return fh    
    
    
def mergesort(head): #Here the algorithm is same as the algorithm used in arrays for sorting.
    if head is None:
        return
    if head.next is None:
        return head    
    mid = midpoint(head)  #Here we find the mid point of Linked list.
    head2= mid.next    #With this we simply break our linked list into two other list.
    mid.next = None
    h1=mergesort(head)
    h2=mergesort(head2)
    h=mergell(h1,h2)
        
    return h
def TakeNodeInput():
    NodeArray=[int(x) for x in input().split()]
    head=None
    tail =None
    for ele in NodeArray:
        if ele == -1:
            break
        NewNode=Node(ele) 
        if head==None:
            head=NewNode
            tail=head
        else:
            tail.next = NewNode
            tail=tail.next
    return head

def PrintLL(head):
    while head!=None:
        print(str(head.data) + '->',end='')
        head=head.next
    print("None")   
    return

head=TakeNodeInput()
PrintLL(head)
head = mergesort(head)
PrintLL(head)
# Out:
# 10 -5 9 90 5 67 1 89 -1
# 10->-5->9->90->5->67->1->89->None
# -5->1->5->9->10->67->89->90->None
