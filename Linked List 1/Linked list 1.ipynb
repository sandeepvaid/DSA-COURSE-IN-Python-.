# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
   
def LengthLL(head):
    count=0
    while head is not None:
        count+=1
        head=head.next
    return count

def printIthNode(head, i):
    L=LengthLL(head,i)
    if L==-1:
        return
    else:
        index=0
        while head is not None:
             if i==index:
                return head.data
             else:
                index+=1
                head=head.next
                
def TakeNodeInput():
    NodeArray=[int(x) for x in input().split()]
    head=None
    tail =None
    for ele in NodeArray:
        if ele == -1:
            break
        NewNode=Node(ele) 
        if head==None:
            head=NewNode
            tail=head
        else:
            tail.next = NewNode
            tail=tail.next
    return head

def PrintLL(head):
    while head!=None:
        print(str(head.data) + '->',end='')
        head=head.next
    print("None")   
    return

head=TakeNodeInput()
PrintLL(head)
#print(LengthLL(head))
#print(printIthNode(head,10))

# %% [markdown]
# Program to insert data at Ith position

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
   
def LengthLL(head):
    count=0
    while head is not None:
        count+=1
        head=head.next
    return count

def Insert_At_Ith_pos(head,data,i):
    if i<0 or i>LengthLL(head):
        return head
    count=0
    curr=head
    prev=None
    while count<i:
        
        prev=curr
        curr=curr.next
        count=count+1  
        
    NewNode=Node(data)
    if prev is None:
        head=NewNode
        NewNode.next=curr
    else:
        prev.next=NewNode
        NewNode.next=curr
        
    return head    
                
def TakeNodeInput():
    NodeArray=[int(x) for x in input().split()]
    head=None
    tail =None
    for ele in NodeArray:
        if ele == -1:
            break
        NewNode=Node(ele) 
        if head==None:
            head=NewNode
            tail=head
        else:
            tail.next = NewNode
            tail=tail.next
    return head

def PrintLL(head):
    while head!=None:
        print(str(head.data) + '->',end='')
        head=head.next
    print("None")   
    return

head=TakeNodeInput()
head1=Insert_At_Ith_pos(head,9,0)
PrintLL(head1)
# Out:
# 1 2 3 4 5
# 9->1->2->3->4->5->None

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
   
def LengthLL(head):
    count=0
    while head is not None:
        count+=1
        head=head.next
    return count

def Delete_At_ith_Pos(head,i):
    if i<0 or i>=LengthLL(head):
        return head
    
    count=0
    curr=head
    prev=None
    while count<i:
        prev=curr
        curr=curr.next
        count=count+1
    if prev is None:
        head=curr.next
    else:
        prev.next=curr.next
    return head    
        
def TakeNodeInput():
    NodeArray=[int(x) for x in input().split()]
    head=None
    tail =None
    for ele in NodeArray:
        if ele == -1:
            break
        NewNode=Node(ele) 
        if head==None:
            head=NewNode
            tail=head
        else:
            tail.next = NewNode
            tail=tail.next
    return head

def PrintLL(head):
    while head!=None:
        print(str(head.data) + '->',end='')
        head=head.next
    print("None")   
    return

head=TakeNodeInput()
PrintLL(head)
head=Delete_At_ith_Pos(head,7)
PrintLL(head)
# Out:
# 10 20 30 40 50 60 -1
# 10->20->30->40->50->60->None
# 10->20->30->40->50->60->None

# %% [markdown]
# Length of linked list recusrsively

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
   
def LengthLL_Recur(head):
    if head == None:
        return 0
    if head.next==None:
        return 1
    small_ip=head.next
    output = 1 + LengthLL_Recur(small_ip)

    return output
    
        
def TakeNodeInput():
    NodeArray=[int(x) for x in input().split()]
    head=None
    tail =None
    for ele in NodeArray:
        if ele == -1:
            break
        NewNode=Node(ele) 
        if head==None:
            head=NewNode
            tail=head
        else:
            tail.next = NewNode
            tail=tail.next
    return head

def PrintLL(head):
    while head!=None:
        print(str(head.data) + '->',end='')
        head=head.next
    print("None")   
    return

head=TakeNodeInput()
LengthLL_Recur(head)
# Out:
# -1
# 0

# %% [markdown]
# Alternate way to write code to check length of linked list recursively

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
   
def LengthLL_Recur(head):
    if head == None:
        return 0
    small_ip=head.next
    output = LengthLL_Recur(small_ip)

    return output+1
    
        
def TakeNodeInput():
    NodeArray=[int(x) for x in input().split()]
    head=None
    tail =None
    for ele in NodeArray:
        if ele == -1:
            break
        NewNode=Node(ele) 
        if head==None:
            head=NewNode
            tail=head
        else:
            tail.next = NewNode
            tail=tail.next
    return head

def PrintLL(head):
    while head!=None:
        print(str(head.data) + '->',end='')
        head=head.next
    print("None")   
    return

head=TakeNodeInput()
LengthLL_Recur(head)
# Out:
# 1 2 3
# 3

# %% [markdown]
# Insert at Ith position recursively

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
   
def LengthLL_Recur(head):
     count=0
    while head is not None:
        count+=1
        head=head.next
    return count
    
  
def Insrt_AT_Ith_pos_Rec(head,data,i):

    if i<0:
        return head
    if i==0:
        NewNode=Node(data)
        NewNode.next=head
        return NewNode

    if head is None:
        return None    
    
    small_ip=head.next
    small_head = Insrt_AT_Ith_pos_Rec(small_ip,data,i-1)
    head.next = small_head
    return head
 
def deleteNodeRec(head, pos) :    
    if pos<0:
        return head
    if pos ==0:
        head=head.next
        return head
    if head is None:
        return None
    
    small_ip= head.next
    small_head = deleteNodeRec(small_ip,pos-1)
    head.next = small_head
    return head

def TakeNodeInput():
    NodeArray=[int(x) for x in input().split()]
    head=None
    tail =None
    for ele in NodeArray:
        if ele == -1:
            break
        NewNode=Node(ele) 
        if head==None:
            head=NewNode
            tail=head
        else:
            tail.next = NewNode
            tail=tail.next
    return head

def PrintLL(head):
    while head!=None:
        print(str(head.data) + '->',end='')
        head=head.next
    print("None")   
    return

head=TakeNodeInput()
LengthLL_Recur(head)
PrintLL(head)
head=Insrt_AT_Ith_pos_Rec(head,9,5)
PrintLL(head)
head=deleteNodeRec(head,5)
PrintLL(head)
# Out:
# 1 2 3 4 5 -1
# 1->2->3->4->5->None
# 1->2->3->4->5->9->None
# 1->2->3->4->5->None

# %% [markdown]
# Find a node in a Linked list in recursive way

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
   
def findNode(head, n) :
    
    if head is None:
        return -1    
    
    if head.data==n:
        return 0

    small_ip = head.next
    output = findNode(small_ip,n)
    if output==-1:
        return -1
    else:
        return output + 1

def TakeNodeInput():
    NodeArray=[int(x) for x in input().split()]
    head=None
    tail =None
    for ele in NodeArray:
        if ele == -1:
            break
        NewNode=Node(ele) 
        if head==None:
            head=NewNode
            tail=head
        else:
            tail.next = NewNode
            tail=tail.next
    return head

def PrintLL(head):
    while head!=None:
        print(str(head.data) + '->',end='')
        head=head.next
    print("None")   
    return

head=TakeNodeInput()
PrintLL(head)
print(findNode(head,6))
# Out:
# 3 4 5 2 6 1 9 -1
# 3->4->5->2->6->1->9->None
# 4

# %% [markdown]
# Find a node in a linked list in iterative way

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None

def LengthLL_Recur(head):
    count=0
    while head is not None:
        count+=1
        head=head.next
    return countt

def findNode(head, n) :
    count=0
    curr=head
    while count<LengthLL_Recur(head):
        if curr.data == n:
            return count
        else:
            count = count+1
            curr= curr.next
    
    return -1
    
def TakeNodeInput():
    NodeArray=[int(x) for x in input().split()]
    head=None
    tail =None
    for ele in NodeArray:
        if ele == -1:
            break
        NewNode=Node(ele) 
        if head==None:
            head=NewNode
            tail=head
        else:
            tail.next = NewNode
            tail=tail.next
    return head

def PrintLL(head):
    while head!=None:
        print(str(head.data) + '->',end='')
        head=head.next
    print("None")   
    return

head=TakeNodeInput()
PrintLL(head)
print(findNode(head,3))
# Out:
# 1 2 3 4 5 3
# 1->2->3->4->5->3->None
# 2

# %% [markdown]
# Program to append last n to first.

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None

def LengthLL_Recur(head):
    count=0
    while head is not None:
        count+=1
        head=head.next
    return count
            
    
def appendLastNToFirst(head, n) :
    l=LengthLL_Recur(head)
    if head is None:
        return
    if n==0 or n==l:
        return head
    if n > l:
        return head
    i=1
    count= l - n
    curr=head
    while i< count:
        curr=curr.next
        i=i+1
    head2=curr.next
    curr.next=None
    count = LengthLL_Recur(head2)
    i=1
    curr=head2
    while i< count:
        curr=curr.next
        i=i+1
    curr.next = head
    return head2
    
def TakeNodeInput():
    NodeArray=[int(x) for x in input().split()]
    head=None
    tail =None
    for ele in NodeArray:
        if ele == -1:
            break
        NewNode=Node(ele) 
        if head==None:
            head=NewNode
            tail=head
        else:
            tail.next = NewNode
            tail=tail.next
    return head

def PrintLL(head):
    while head!=None:
        print(str(head.data) + '->',end='')
        head=head.next
    print("None")   
    return

head=TakeNodeInput()
PrintLL(head)
head = appendLastNToFirst(head,1)
PrintLL(head)
# Out:
# 1 2 3
# 1->2->3->None
# 3->1->2->None

# %% [markdown]
# Program to remove consecutive duplicates from linked list

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
            
def removeDuplicates(head) :
    prev = head
    curr = head.next
    while curr.next is not None:
        if prev.data == curr.data:
            curr=curr.next
        else:
            prev.next = curr
            prev=curr
            curr = curr.next
    if prev.data == curr.data:
        prev.next=None
        return head
    else:
        prev.next = curr 
        return head

    
def TakeNodeInput():
    NodeArray=[int(x) for x in input().split()]
    head=None
    tail =None
    for ele in NodeArray:
        if ele == -1:
            break
        NewNode=Node(ele) 
        if head==None:
            head=NewNode
            tail=head
        else:
            tail.next = NewNode
            tail=tail.next
    return head

def PrintLL(head):
    while head!=None:
        print(str(head.data) + '->',end='')
        head=head.next
    print("None")   
    return

head=TakeNodeInput()
PrintLL(head)
head =removeDuplicates(head)
PrintLL(head)
# Out:
# 10 10 10 10 -1
# 10->10->10->10->None
# 10->None

# %% [markdown]
# program to print reverse of linked list

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None

def printReverse(head):
    curr=head
    frwd=None
    prev=None
    while curr is not None:
        frwd = curr.next
        curr.next = prev
        prev = curr
        curr = frwd
    return prev    

def TakeNodeInput():
    NodeArray=[int(x) for x in input().split()]
    head=None
    tail =None
    for ele in NodeArray:
        if ele == -1:
            break
        NewNode=Node(ele) 
        if head==None:
            head=NewNode
            tail=head
        else:
            tail.next = NewNode
            tail=tail.next
    return head

def PrintLL(head):
    while head!=None:
        print(str(head.data) + '->',end='')
        head=head.next
    print("None")   
    return

head=TakeNodeInput()
PrintLL(head)
head=printReverse(head)
PrintLL(head)
# Out:
# 1 2 3
# 1->2->3->None
# 3->2->1->None

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None

def LengthLL(head):
    count=0
    while head is not None:
        count+=1
        head=head.next
    return count
        
def rev(h2):  ## TO understand that only need to dry run that code
    curr=head
    frwd=None
    prev=None
    while curr is not None:
        frwd = curr.next
        curr.next = prev
        prev = curr
        curr = frwd
    return prev  

def isPalindrome(head):
    l=LengthLL(head)
    mid=l//2
    i=1
    curr=head
    while i<mid:
        curr=curr.next
        i=i+1
    head2 = curr.next
    curr.next= None
    head3 =rev(head2)
    while head is not None and head3 is not None:
        if head.data==head3.data:
            head = head.next
            head3 = head3.next
        else:
            return False
    while head is None or head3  is None:
        return True
    
def TakeNodeInput():
    NodeArray=[int(x) for x in input().split()]
    head=None
    tail =None
    for ele in NodeArray:
        if ele == -1:
            break
        NewNode=Node(ele) 
        if head==None:
            head=NewNode
            tail=head
        else:
            tail.next = NewNode
            tail=tail.next
    return head

def PrintLL(head):
    while head!=None:
        print(str(head.data) + '->',end='')
        head=head.next
    print("None")   
    return

head=TakeNodeInput()
PrintLL(head)
#h2=rev(head)
#PrintLL(h2)
ans = isPalindrome(head)
if ans: 
    print("true")
else:
    print("false")
# Out:
# 1 2 1
# 1->2->1->None
# true

# %%
def rev(num):
    ne = num
    rev=0
    while ne!=0:
        md=ne%10
        ne=ne//10
        rev = rev *10 + md
    return rev  
t=int(input())
while t>0:
    num = int(input())
    print(rev(num))
    t=t-1
# Out:
# 4
# 123
# 321
# 410
# 14
# 123658
# 856321
# 154
# 451
