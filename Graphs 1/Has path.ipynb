# %%
#Approch 1(approch 2 is recommended)
class Graph:
    def __init__(self,nVertices):
        self.nVertices = nVertices
        self.AdjacenyMatrix = [[0 for i in range(self.nVertices)] for j in range(self.nVertices)]
        
    def addentry(self,v1,v2):
        self.AdjacenyMatrix[v1][v2] = 1
        self.AdjacenyMatrix[v2][v1] = 1
        
    def deleteentry(self,v1,v2):
        if self.containedges(v1,v2) is False:
            return
        self.AdjacenyMatrix[v1][v2] = 0
        self.AdjacenyMatrix[v2][v1] = 0
        
    def __dfsHelper(self,sv,visited):
        
        print(sv)
        visited[sv] = True
        for i in range(self.nVertices):
            if self.AdjacenyMatrix[sv][i] > 0 and visited[i] == False:
                self.__dfsHelper(i,visited)
        
    def __haspathHelper(self,v1,v2,visited):
        if v1 == v2:
            return True
        visited[v1] = True
        for i in range(self.nVertices):
            if self.AdjacenyMatrix[v1][i] > 0 and visited[i] == False:
                return self.__haspathHelper(i,v2,visited)
        return False    
        
    def haspath(self,v1,v2):
        if self.AdjacenyMatrix[v1][v2] == 1:
            return True
        visited = [False for i in range(self.nVertices)]
        return self.__haspathHelper(v1,v2,visited)
        
    def dfs(self):
        sv = 0
        visited = [False for i in range(self.nVertices)]
        for i in range(self.nVertices):
            if visited[i] is False:
                self.__dfsHelper(i,visited)
        
    def containedges(self,v1,v2):
        return True if self.AdjacenyMatrix[v1][v2] == 1 else  False
        
    def __str__(self):
        return str(self.AdjacenyMatrix)
    
    
VE = [int(i) for i in input().split()]
n = VE[0]
e = VE[1]
if e == 0 and n == 0:
    print('true')
else:    
    g = Graph(n)
    while e > 0:
        edges = [int(i) for i in input().split()]
        g.addentry(edges[0],edges[1])
        e = e - 1
    vertices = [int(i) for i in input().split()]
    ans = g.haspath(vertices[0],vertices[1])
    if ans:
        print("true")
    else:
        print("false")
# Out:
# 4 4
# 0 1
# 0 3
# 1 2
# 1 3
# 1 3
# true

# %%
#Approch 2nd(recommended)
class Graph:
    def __init__(self,nVertices):
        self.nVertices = nVertices
        self.AdjacenyMatrix = [[0 for i in range(self.nVertices)] for j in range(self.nVertices)]
        
    def addentry(self,v1,v2):
        self.AdjacenyMatrix[v1][v2] = 1
        self.AdjacenyMatrix[v2][v1] = 1
        
    def deleteentry(self,v1,v2):
        if self.containedges(v1,v2) is False:
            return
        self.AdjacenyMatrix[v1][v2] = 0
        self.AdjacenyMatrix[v2][v1] = 0
        
    def __dfsHelper(self,sv,visited):
        
        print(sv)
        visited[sv] = True
        for i in range(self.nVertices):
            if self.AdjacenyMatrix[sv][i] > 0 and visited[i] == False:
                self.__dfsHelper(i,visited)
        
    def __haspathHelper(self,v1,v2,visited):
        visited[v1] = True
        for i in range(self.nVertices):
            if self.AdjacenyMatrix[v1][i] > 0 and visited[i] == False:
                self.__haspathHelper(i,v2,visited)    
        
    def haspath(self,v1,v2):
        if self.AdjacenyMatrix[v1][v2] == 1:
            return True
        visited = [False for i in range(self.nVertices)]
        self.__haspathHelper(v1,v2,visited)
        if visited[v2] == True:
            return True
        else:
            return False
        
    def dfs(self):
        sv = 0
        visited = [False for i in range(self.nVertices)]
        for i in range(self.nVertices):
            if visited[i] is False:
                self.__dfsHelper(i,visited)
        
    def containedges(self,v1,v2):
        return True if self.AdjacenyMatrix[v1][v2] == 1 else  False
        
    def __str__(self):
        return str(self.AdjacenyMatrix)
    
    
VE = [int(i) for i in input().split()]
n = VE[0]
e = VE[1]
if e == 0 and n == 0:
    print('true')
else:    
    g = Graph(n)
    while e > 0:
        edges = [int(i) for i in input().split()]
        g.addentry(edges[0],edges[1])
        e = e - 1
    vertices = [int(i) for i in input().split()]
    ans = g.haspath(vertices[0],vertices[1])
    if ans:
        print("true")
    else:
        print("false")
# Out:
# 4 4
# 0 1
# 0 3
# 1 2
# 2 3
# 1 3
# true

# %%
5>=5
# Out:
# True
